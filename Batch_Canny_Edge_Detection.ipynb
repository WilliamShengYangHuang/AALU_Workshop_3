# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamShengYangHuang/AALU_Workshop_3/blob/main/Batch_Canny_Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import math
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_folder = '/content/drive/MyDrive/poi_images_around_Trafalgar_Square'  #@param{type:'string'}
output_folder = '/content/drive/MyDrive/Canny_output_folder'  #@param{type:'string'}

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
# Supported image formats
image_extensions = ('.jpg', '.jpeg', '.png')

# Store original and edge-detected images
original_images = []
edge_images = []

# Process images
for filename in os.listdir(input_folder):
    if filename.lower().endswith(image_extensions):
        input_path = os.path.join(input_folder, filename)

        # Read the image
        img = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)  # Convert to greyscale for edge detection
        if img is None:
            print(f"Cannot read file: {filename}")
            continue

        # Perform Canny edge detection
        threshold1 = 100  #@param{type:'slider', min:0, max:255, step:1}
        threshold2 = 200  #@param{type:'slider', min:0, max:255, step:1}
        edges = cv2.Canny(img, threshold1, threshold2)

        # Save images in lists for later visualisation
        original_images.append(img)
        edge_images.append(edges)

        # Save the edge detection result to the output folder
        output_path = os.path.join(output_folder, f'canny_{filename}')
        cv2.imwrite(output_path, edges)
        print(f"Processing completed and saved: {output_path}")

# Dynamically calculate the grid size
num_images = len(original_images)  # Total number of original images
num_subplots = num_images * 2  # Two subplots for each image (original + edges)
cols = 4  # Fixed number of columns
rows = math.ceil(num_subplots / cols)  # Calculate the number of rows needed

# Create the figure and axes
fig, axs = plt.subplots(rows, cols, figsize=(cols * 5, rows * 5), dpi=150)

# Flatten the axes array for easy indexing
axs = axs.flatten()

# Display the images
for i in range(num_images):
    # Original image
    axs[i * 2].imshow(original_images[i], cmap='gray')
    axs[i * 2].set_title('Original Image')
    axs[i * 2].axis('off')

    # Edge-detected image
    axs[i * 2 + 1].imshow(edge_images[i], cmap='gray')
    axs[i * 2 + 1].set_title('Canny Edges')
    axs[i * 2 + 1].axis('off')

# Hide unused subplots
for j in range(num_images * 2, len(axs)):
    axs[j].axis('off')

# Adjust layout and display
plt.tight_layout()
plt.show()

print("All images have been processed and visualised!")
# Out:
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJYxIC5M4EdkgR1KNQDHX_n1k_1.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJJ8HlTsUEdkgRgPkf7Km4LbQ_2.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJm8X-9M0EdkgR7OfNHW6yApM_3.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ7X-thtEEdkgRiLXpFZkYHP0_4.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJU0_GCNIEdkgRFFmOhiqR4Ts_5.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJZewrLtIEdkgRtl2nZKboAgk_6.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJF4PizM0EdkgRRMPLsE5qX_0_7.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJG6soKcwEdkgRN5Q-HvqfMbc_8.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJs_wVR9IEdkgRqColcXYGFE0_9.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJc6MfdM8EdkgRC61xcbX79DA_10.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ78fbAc8EdkgRWG1dhffz9AY_11.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJRyjaAc8EdkgREzqR4nCwT-U_12.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJZf2Jlc4EdkgRklHks51KYBo_13.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJc9zIO88EdkgRtiF_0UhDLZk_14.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJVUIwx80EdkgRoJcAipJhY7E_15.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJcW-weM8EdkgRbcMBNMcmUto_16.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJeclqF84EdkgRYkL4mtJ7rLM_17.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJc9zIO88EdkgRg0nPO7WZ5Jw_18.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJYeck5s4EdkgRz2496L-49us_19.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJZZHSP9IEdkgR0k3AunsRbHo_20.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJq0hKWNEEdkgRUTisX89yDCM_21.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJF-WCA9IEdkgRnhW704RFvCI_22.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJczGN-CgFdkgRSlnkCe50MQI_23.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJvWTxTM4EdkgRY2f_V0GXNgI_24.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJR4xZKNIEdkgRS3b1rjIWbRQ_25.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJt2xYKc4EdkgRiSOCe1hI2zU_26.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ65xzsc8EdkgR1CPqm1x5rsU_27.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJH-tBOc4EdkgRJ8aJ8P1CUxo_28.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJKU7H_9AEdkgR4yo4FD1eNXc_29.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJJUyxFNIEdkgRajb-0tlYT_0_30.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ24-dOtIEdkgRUdpPyAD1PmI_31.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJdfveOc4EdkgRafyvBawIUJE_32.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJIQGWCMwEdkgRi9ZJfYJvxak_33.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJO5olhdEEdkgRJF0dAtgtpVQ_34.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJl2FFos0EdkgRvC7jf0mvDf8_35.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJq8MdGtIEdkgRFna59Q2kMh4_36.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJQZwYi80EdkgR58WSdE7oUro_37.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJnViY484EdkgRRuivNzAt-hI_38.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJexYS8tEEdkgRoOLWbHv1IHg_39.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJpwrHSNAEdkgR1YO1RjflYXw_40.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJyVxL7M0EdkgRofovT3fX5ZE_41.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJL9282tMEdkgRVF0ZcphVxtc_42.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJKXTZKcwEdkgRZs8E0eH5zVI_43.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJeclqF84EdkgRtKAjTmWFr0I_44.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ9Watyc0EdkgRNCGspYgasFk_45.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ_3vAw9EEdkgRWuJSejzv9fA_46.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJDVBtxs4EdkgRrFuVtkDtSP0_47.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ78fbAc8EdkgRpl7qmBRwPKU_48.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJC0NJGMwEdkgRg6RWBJ_l_cY_49.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJdbUSy1cDdkgRMxhBCU1wrlw_50.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ0dU6L88EdkgRSRva6TI0lsY_51.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJW58eotEEdkgRr6-cmS2kqCQ_52.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJf8FhJc8EdkgR7xfnalN2O0U_53.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJV00rzdMEdkgR-DdcfCvtiYk_54.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJSWvAzM4EdkgRaZcCMhRbk0Q_55.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJz-VvsdMEdkgR1lQfyxijRMw_56.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJYR4kldEEdkgRvGYYfdFgcIc_57.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ8xZFCNIEdkgRh6ulrAY-hOw_58.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJkWJjuc0EdkgRqL0ffd2j1aA_59.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJH1D0jtQadkgRmLkZ5tQG4dY_60.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJnViY484EdkgRRuivNzAt-hI_1.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJH1D0jtQadkgRmLkZ5tQG4dY_2.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJDVBtxs4EdkgRrFuVtkDtSP0_3.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJq0hKWNEEdkgRUTisX89yDCM_4.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJczGN-CgFdkgRSlnkCe50MQI_5.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJL9282tMEdkgRVF0ZcphVxtc_6.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJC0NJGMwEdkgRg6RWBJ_l_cY_7.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJYR4kldEEdkgRvGYYfdFgcIc_8.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJZf2Jlc4EdkgRklHks51KYBo_9.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJq8MdGtIEdkgRFna59Q2kMh4_10.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJz-VvsdMEdkgR1lQfyxijRMw_11.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ0dU6L88EdkgRSRva6TI0lsY_12.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJkWJjuc0EdkgRqL0ffd2j1aA_13.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJR4xZKNIEdkgRS3b1rjIWbRQ_14.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ9Watyc0EdkgRNCGspYgasFk_15.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJO5olhdEEdkgRJF0dAtgtpVQ_16.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ7X-thtEEdkgRiLXpFZkYHP0_17.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJyVxL7M0EdkgRofovT3fX5ZE_18.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ78fbAc8EdkgRpl7qmBRwPKU_19.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJl2FFos0EdkgRvC7jf0mvDf8_20.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJc6MfdM8EdkgRC61xcbX79DA_21.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJJ8HlTsUEdkgRgPkf7Km4LbQ_22.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJF-WCA9IEdkgRnhW704RFvCI_23.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ_3vAw9EEdkgRWuJSejzv9fA_24.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJeclqF84EdkgRYkL4mtJ7rLM_25.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJs_wVR9IEdkgRqColcXYGFE0_26.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJW58eotEEdkgRr6-cmS2kqCQ_27.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJeclqF84EdkgRtKAjTmWFr0I_28.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJf8FhJc8EdkgR7xfnalN2O0U_29.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJdfveOc4EdkgRafyvBawIUJE_30.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJcW-weM8EdkgRbcMBNMcmUto_31.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ78fbAc8EdkgRWG1dhffz9AY_32.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJJUyxFNIEdkgRajb-0tlYT_0_33.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJc9zIO88EdkgRtiF_0UhDLZk_34.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJt2xYKc4EdkgRiSOCe1hI2zU_35.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ65xzsc8EdkgR1CPqm1x5rsU_36.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJm8X-9M0EdkgR7OfNHW6yApM_37.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJZewrLtIEdkgRtl2nZKboAgk_38.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJVUIwx80EdkgRoJcAipJhY7E_39.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ8xZFCNIEdkgRh6ulrAY-hOw_40.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJdbUSy1cDdkgRMxhBCU1wrlw_41.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJZZHSP9IEdkgR0k3AunsRbHo_42.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJIQGWCMwEdkgRi9ZJfYJvxak_43.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJvWTxTM4EdkgRY2f_V0GXNgI_44.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJpwrHSNAEdkgR1YO1RjflYXw_45.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJexYS8tEEdkgRoOLWbHv1IHg_46.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJRyjaAc8EdkgREzqR4nCwT-U_47.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJYxIC5M4EdkgR1KNQDHX_n1k_48.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJQZwYi80EdkgR58WSdE7oUro_49.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJKXTZKcwEdkgRZs8E0eH5zVI_50.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJU0_GCNIEdkgRFFmOhiqR4Ts_51.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJc9zIO88EdkgRg0nPO7WZ5Jw_52.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJV00rzdMEdkgR-DdcfCvtiYk_53.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJG6soKcwEdkgRN5Q-HvqfMbc_54.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJF4PizM0EdkgRRMPLsE5qX_0_55.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJSWvAzM4EdkgRaZcCMhRbk0Q_56.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJKU7H_9AEdkgR4yo4FD1eNXc_57.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJYeck5s4EdkgRz2496L-49us_58.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJH-tBOc4EdkgRJ8aJ8P1CUxo_59.jpg
# Processing completed and saved: /content/drive/MyDrive/Canny_output_folder/canny_trafalgar_square_ChIJ24-dOtIEdkgRUdpPyAD1PmI_60.jpg
